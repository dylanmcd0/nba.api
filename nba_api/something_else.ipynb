# %%
from basketball_reference_web_scraper import client
import pandas as pd

# %%
boxscores = client.player_box_scores(day = 1, month = 3, year = 2023)

# %%
boxscore_df = pd.DataFrame(boxscores)

# %%
boxscore_df
# Out:
#           slug             name                         team       location  \
# 0    tatumja01     Jayson Tatum          Team.BOSTON_CELTICS  Location.HOME
# 1    brunsja01    Jalen Brunson         Team.NEW_YORK_KNICKS  Location.HOME
# 2    ingrabr01   Brandon Ingram    Team.NEW_ORLEANS_PELICANS  Location.AWAY
# 3    bookede01     Devin Booker            Team.PHOENIX_SUNS  Location.AWAY
# 4    lavinza01      Zach LaVine           Team.CHICAGO_BULLS  Location.AWAY
# ..         ...              ...                          ...            ...
# 185  kennalu01     Luke Kennard       Team.MEMPHIS_GRIZZLIES  Location.AWAY
# 186  littlna01    Nassir Little  Team.PORTLAND_TRAIL_BLAZERS  Location.HOME
# 187  muscami01     Mike Muscala          Team.BOSTON_CELTICS  Location.HOME
# 188  vincega01     Gabe Vincent              Team.MIAMI_HEAT  Location.HOME
# 189  washity02  TyTy Washington         Team.HOUSTON_ROCKETS  Location.HOME
#
# ...

# %%
season_df = pd.DataFrame(client.players_season_totals(season_end_year=2023))

# %%
season_df
# Out:
#           slug                name                  positions  age  \
# 0    achiupr01    Precious Achiuwa          [Position.CENTER]   23
# 1    adamsst01        Steven Adams          [Position.CENTER]   29
# 2    adebaba01         Bam Adebayo          [Position.CENTER]   25
# 3    agbajoc01        Ochai Agbaji  [Position.SHOOTING_GUARD]   22
# 4    aldamsa01        Santi Aldama   [Position.POWER_FORWARD]   22
# ..         ...                 ...                        ...  ...
# 565  wrighmc01  McKinley Wright IV     [Position.POINT_GUARD]   24
# 566  youngth01      Thaddeus Young   [Position.POWER_FORWARD]   34
# 567  youngtr01          Trae Young     [Position.POINT_GUARD]   24
# 568  zelleco01         Cody Zeller          [Position.CENTER]   30
# 569  zubaciv01         Ivica Zubac          [Position.CENTER]   25
#
#                           team  games_played  games_started  minutes_played  \
# 0         Team.TORONTO_RAPTORS            39             11             896
# ...
